# %%
def import_housing_data(url):
    import pandas as pd

    df = pd.read_csv(url)
    df.drop(columns=['Id'], inplace=True)
    df.dropna(axis=1, inplace=True)
    
    return df


import functions as fun
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.options.display.float_format = '{:.5f}'.format
df = import_housing_data('http://www.ishelp.info/data/housing_full.csv')
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# 0            7            5       2003          2003     Gable  CompShg
# 1            6            8       1976          1976     Gable  CompShg
# 2            7            5       2001          2002     Gable  CompShg
# 3            7            5       1915          1970     Gable  CompShg
# 4            8            5       2000          2000     Gable  CompShg
#
#   Exterior1st Exterior2nd ExterQual ExterCond Foundation  BsmtFinSF1  \
# 0     VinylSd     VinylSd        Gd        TA      PConc         706
# 1     MetalSd     MetalSd        TA        TA     CBlock         978
# 2     VinylSd     VinylSd        Gd        TA      PConc         486
# 3     Wd Sdng     Wd Shng        TA        TA     BrkTil         216
# 4     VinylSd     VinylSd        Gd        TA      PConc         655
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  1stFlrSF  \
# 0           0        150          856    GasA        Ex          Y       856
# 1           0        284         1262    GasA        Ex          Y      1262
# 2           0        434          920    GasA        Ex          Y       920
# 3           0        540          756    GasA        Gd          Y       961
# 4           0        490         1145    GasA        Ex          Y      1145
#
#    2ndFlrSF  LowQualFinSF  TotalSF  BsmtFullBath  BsmtHalfBath  FullBath  \
# 0       854             0     1710             1             0         2
# 1         0             0     1262             0             1         2
# 2       866             0     1786             1             0         2
# 3       756             0     1717             1             0         1
# 4      1053             0     2198             1             0         2
#
#    HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 0         1             3             1          Gd             8        Typ
# 1         0             3             1          TA             6        Typ
# 2         1             3             1          Gd             6        Typ
# 3         0             3             1          Gd             7        Typ
# 4         1             4             1          Gd             9        Typ
#
#    Fireplaces  GarageCars  GarageArea PavedDrive  WoodDeckSF  OpenPorchSF  \
# 0           0           2         548          Y           0           61
# 1           1           2         460          Y         298            0
# 2           1           2         608          Y           0           42
# 3           1           3         642          Y           0           35
# 4           1           3         836          Y         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
# !ls
# Out:
# 'Housing Prices.ipynb'	 functions.py		   housing_full.csv
#  __pycache__		 housing_description.txt

# %% [markdown]
# ## Unistats

# %%
# import sys
# sys.path.append('./006-Housing-Prices/')
import functions as fun

            
# ## Test the Function
# import pandas as pd
# pd.set_option('display.max_rows', 100)
# pd.set_option('display.max_columns', 100)
# df = pd.read_csv('http://www.ishelp.info/data/housing_full.csv')
# unistats(df)


fun.unistats(df)
# Out:
#                Count  Missing  Unique   Dtype  Numeric     Mode         Mean  \
# MiscVal         1460        0      21   int64     True        0     43.48904
# PoolArea        1460        0       8   int64     True        0      2.75890
# LotArea         1460        0    1073   int64     True     7200  10516.82808
# 3SsnPorch       1460        0      20   int64     True        0      3.40959
# LowQualFinSF    1460        0      24   int64     True        0      5.84452
# KitchenAbvGr    1460        0       4   int64     True        1      1.04658
# BsmtFinSF2      1460        0     144   int64     True        0     46.54932
# ScreenPorch     1460        0      76   int64     True        0     15.06096
# BsmtHalfBath    1460        0       3   int64     True        0      0.05753
# EnclosedPorch   1460        0     120   int64     True        0     21.95411
# OpenPorchSF     1460        0     202   int64     True        0     46.66027
# SalePrice       1460        0     663   int64     True   140000 180921.19589
# BsmtFinSF1      1460        0     637   int64     True        0    443.63973
# WoodDeckSF      1460        0     274   int64     True        0     94.24452
# TotalBsmtSF     1460        0     721   int64     True        0   1057.42945
# MSSubClass      1460        0      15   int64     True       20     56.89726
# 1stFlrSF        1460        0     753   int64     True      864   1162.62671
# TotalSF         1460        0     861   int64     True      864   1515.46370
# BsmtUnfSF       1460        0     780   int64     True        0    567.24041
# 2ndFlrSF        1460        0     417   int64     True        0    346.99247
# OverallCond     1460        0       9   int64     True        5      5.57534
# TotRmsAbvGrd    1460        0      12   int64     True        6      6.51781
# HalfBath        1460        0       3   int64     True        0      0.38288
# Fireplaces      1460        0       4   int64     True        0      0.61301
# BsmtFullBath    1460        0       4   int64     True        0      0.42534
# OverallQual     1460        0      10   int64     True        5      6.09932
# MoSold          1460        0      12   int64     True        6      6.32192
# BedroomAbvGr    1460        0       8   int64     True        3      2.86644
# GarageArea      1460        0     441   int64     True        0    472.98014
# YrSold          1460        0       5   int64     True     2009   2007.81575
# FullBath        1460        0       4   int64     True        2      1.56507
# GarageCars      1460        0       5   int64     True        2      1.76712
# YearRemodAdd    1460        0      61   int64     True     1950   1984.86575
# YearBuilt       1460        0     112   int64     True     2006   1971.26781
# Neighborhood    1460        0      25  object    False    NAmes            -
# Exterior2nd     1460        0      16  object    False  VinylSd            -
# Exterior1st     1460        0      15  object    False  VinylSd            -
# Condition1      1460        0       9  object    False     Norm            -
# SaleType        1460        0       9  object    False       WD            -
# Condition2      1460        0       8  object    False     Norm            -
# HouseStyle      1460        0       8  object    False   1Story            -
# RoofMatl        1460        0       8  object    False  CompShg            -
# Functional      1460        0       7  object    False      Typ            -
# RoofStyle       1460        0       6  object    False    Gable            -
# Foundation      1460        0       6  object    False    PConc            -
# Heating         1460        0       6  object    False     GasA            -
# SaleCondition   1460        0       6  object    False   Normal            -
# MSZoning        1460        0       5  object    False       RL            -
# LotConfig       1460        0       5  object    False   Inside            -
# BldgType        1460        0       5  object    False     1Fam            -
# ExterCond       1460        0       5  object    False       TA            -
# HeatingQC       1460        0       5  object    False       Ex            -
# LotShape        1460        0       4  object    False      Reg            -
# LandContour     1460        0       4  object    False      Lvl            -
# ExterQual       1460        0       4  object    False       TA            -
# KitchenQual     1460        0       4  object    False       TA            -
# LandSlope       1460        0       3  object    False      Gtl            -
# PavedDrive      1460        0       3  object    False        Y            -
# Street          1460        0       2  object    False     Pave            -
# Utilities       1460        0       2  object    False   AllPub            -
# CentralAir      1460        0       2  object    False        Y            -
#
#                  Min          25%       Median          75%     Max  \
# MiscVal            0      0.00000      0.00000      0.00000   15500
# PoolArea           0      0.00000      0.00000      0.00000     738
# LotArea         1300   7553.50000   9478.50000  11601.50000  215245
# 3SsnPorch          0      0.00000      0.00000      0.00000     508
# LowQualFinSF       0      0.00000      0.00000      0.00000     572
# KitchenAbvGr       0      1.00000      1.00000      1.00000       3
# BsmtFinSF2         0      0.00000      0.00000      0.00000    1474
# ScreenPorch        0      0.00000      0.00000      0.00000     480
# BsmtHalfBath       0      0.00000      0.00000      0.00000       2
# EnclosedPorch      0      0.00000      0.00000      0.00000     552
# OpenPorchSF        0      0.00000     25.00000     68.00000     547
# SalePrice      34900 129975.00000 163000.00000 214000.00000  755000
# BsmtFinSF1         0      0.00000    383.50000    712.25000    5644
# WoodDeckSF         0      0.00000      0.00000    168.00000     857
# TotalBsmtSF        0    795.75000    991.50000   1298.25000    6110
# MSSubClass        20     20.00000     50.00000     70.00000     190
# 1stFlrSF         334    882.00000   1087.00000   1391.25000    4692
# TotalSF          334   1129.50000   1464.00000   1776.75000    5642
# BsmtUnfSF          0    223.00000    477.50000    808.00000    2336
# 2ndFlrSF           0      0.00000      0.00000    728.00000    2065
# OverallCond        1      5.00000      5.00000      6.00000       9
# TotRmsAbvGrd       2      5.00000      6.00000      7.00000      14
# HalfBath           0      0.00000      0.00000      1.00000       2
# Fireplaces         0      0.00000      1.00000      1.00000       3
# BsmtFullBath       0      0.00000      0.00000      1.00000       3
# OverallQual        1      5.00000      6.00000      7.00000      10
# MoSold             1      5.00000      6.00000      8.00000      12
# BedroomAbvGr       0      2.00000      3.00000      3.00000       8
# GarageArea         0    334.50000    480.00000    576.00000    1418
# YrSold          2006   2007.00000   2008.00000   2009.00000    2010
# FullBath           0      1.00000      2.00000      2.00000       3
# GarageCars         0      1.00000      2.00000      2.00000       4
# YearRemodAdd    1950   1967.00000   1994.00000   2004.00000    2010
# YearBuilt       1872   1954.00000   1973.00000   2000.00000    2010
# Neighborhood       -            -            -            -       -
# Exterior2nd        -            -            -            -       -
# Exterior1st        -            -            -            -       -
# Condition1         -            -            -            -       -
# SaleType           -            -            -            -       -
# Condition2         -            -            -            -       -
# HouseStyle         -            -            -            -       -
# RoofMatl           -            -            -            -       -
# Functional         -            -            -            -       -
# RoofStyle          -            -            -            -       -
# Foundation         -            -            -            -       -
# Heating            -            -            -            -       -
# SaleCondition      -            -            -            -       -
# MSZoning           -            -            -            -       -
# LotConfig          -            -            -            -       -
# BldgType           -            -            -            -       -
# ExterCond          -            -            -            -       -
# HeatingQC          -            -            -            -       -
# LotShape           -            -            -            -       -
# LandContour        -            -            -            -       -
# ExterQual          -            -            -            -       -
# KitchenQual        -            -            -            -       -
# LandSlope          -            -            -            -       -
# PavedDrive         -            -            -            -       -
# Street             -            -            -            -       -
# Utilities          -            -            -            -       -
# CentralAir         -            -            -            -       -
#
#                       Std     Skew      Kurt
# MiscVal         496.12302 24.47679 701.00334
# PoolArea         40.17731 14.82837 223.26850
# LotArea        9981.26493 12.20769 203.24327
# 3SsnPorch        29.31733 10.30434 123.66238
# LowQualFinSF     48.62308  9.01134  83.23482
# KitchenAbvGr      0.22034  4.48840  21.53240
# BsmtFinSF2      161.31927  4.25526  20.11334
# ScreenPorch      55.75742  4.12221  18.43907
# BsmtHalfBath      0.23875  4.10340  16.39664
# EnclosedPorch    61.11915  3.08987  10.43077
# OpenPorchSF      66.25603  2.36434   8.49034
# SalePrice     79442.50288  1.88288   6.53628
# BsmtFinSF1      456.09809  1.68550  11.11824
# WoodDeckSF      125.33879  1.54138   2.99295
# TotalBsmtSF     438.70532  1.52425  13.25048
# MSSubClass       42.30057  1.40766   1.58019
# 1stFlrSF        386.58774  1.37676   5.74584
# TotalSF         525.48038  1.36656   4.89512
# BsmtUnfSF       441.86696  0.92027   0.47499
# 2ndFlrSF        436.52844  0.81303  -0.55346
# OverallCond       1.11280  0.69307   1.10641
# TotRmsAbvGrd      1.62539  0.67634   0.88076
# HalfBath          0.50289  0.67590  -1.07693
# Fireplaces        0.64467  0.64957  -0.21724
# BsmtFullBath      0.51891  0.59607  -0.83910
# OverallQual       1.38300  0.21694   0.09629
# MoSold            2.70363  0.21205  -0.40411
# BedroomAbvGr      0.81578  0.21179   2.23087
# GarageArea      213.80484  0.17998   0.91707
# YrSold            1.32810  0.09627  -1.19060
# FullBath          0.55092  0.03656  -0.85704
# GarageCars        0.74732 -0.34255   0.22100
# YearRemodAdd     20.64541 -0.50356  -1.27225
# YearBuilt        30.20290 -0.61346  -0.43955
# Neighborhood            -        -         -
# Exterior2nd             -        -         -
# Exterior1st             -        -         -
# Condition1              -        -         -
# SaleType                -        -         -
# Condition2              -        -         -
# HouseStyle              -        -         -
# RoofMatl                -        -         -
# Functional              -        -         -
# RoofStyle               -        -         -
# Foundation              -        -         -
# Heating                 -        -         -
# SaleCondition           -        -         -
# MSZoning                -        -         -
# LotConfig               -        -         -
# BldgType                -        -         -
# ExterCond               -        -         -
# HeatingQC               -        -         -
# LotShape                -        -         -
# LandContour             -        -         -
# ExterQual               -        -         -
# KitchenQual             -        -         -
# LandSlope               -        -         -
# PavedDrive              -        -         -
# Street                  -        -         -
# Utilities               -        -         -
# CentralAir              -        -         -

# %%
fun.bivstats(df, 'SalePrice')
# Out:
#               Stat      +/-  Effect size  p-value
# OverallQual      r  1.00000      0.79100  0.00000
# TotalSF          r  1.00000      0.70900  0.00000
# GarageCars       r  1.00000      0.64000  0.00000
# GarageArea       r  1.00000      0.62300  0.00000
# TotalBsmtSF      r  1.00000      0.61400  0.00000
# 1stFlrSF         r  1.00000      0.60600  0.00000
# FullBath         r  1.00000      0.56100  0.00000
# TotRmsAbvGrd     r  1.00000      0.53400  0.00000
# YearBuilt        r  1.00000      0.52300  0.00000
# YearRemodAdd     r  1.00000      0.50700  0.00000
# Fireplaces       r  1.00000      0.46700  0.00000
# BsmtFinSF1       r  1.00000      0.38600  0.00000
# WoodDeckSF       r  1.00000      0.32400  0.00000
# 2ndFlrSF         r  1.00000      0.31900  0.00000
# OpenPorchSF      r  1.00000      0.31600  0.00000
# HalfBath         r  1.00000      0.28400  0.00000
# LotArea          r  1.00000      0.26400  0.00000
# BsmtFullBath     r  1.00000      0.22700  0.00000
# BsmtUnfSF        r  1.00000      0.21400  0.00000
# BedroomAbvGr     r  1.00000      0.16800  0.00000
# KitchenAbvGr     r -1.00000      0.13600  0.00000
# EnclosedPorch    r -1.00000      0.12900  0.00000
# ScreenPorch      r  1.00000      0.11100  0.00002
# PoolArea         r  1.00000      0.09200  0.00041
# MSSubClass       r -1.00000      0.08400  0.00127
# OverallCond      r -1.00000      0.07800  0.00291
# MoSold           r  1.00000      0.04600  0.07613
# 3SsnPorch        r  1.00000      0.04500  0.08858
# YrSold           r -1.00000      0.02900  0.26941
# LowQualFinSF     r -1.00000      0.02600  0.32821
# MiscVal          r -1.00000      0.02100  0.41849
# BsmtHalfBath     r -1.00000      0.01700  0.52015
# BsmtFinSF2       r -1.00000      0.01100  0.66400
# ExterQual        F             443.33500  0.00000
# KitchenQual      F             407.80600  0.00000
# Foundation       F             100.25400  0.00000
# CentralAir       F              98.30500  0.00000
# HeatingQC        F              88.39400  0.00000
# Neighborhood     F              71.78500  0.00000
# SaleCondition    F              45.57800  0.00000
# MSZoning         F              43.84000  0.00000
# PavedDrive       F              42.02400  0.00000
# LotShape         F              40.13300  0.00000
# SaleType         F              28.86300  0.00000
# HouseStyle       F              19.59500  0.00000
# Exterior1st      F              18.61200  0.00000
# RoofStyle        F              17.80500  0.00000
# Exterior2nd      F              17.50100  0.00000
# BldgType         F              13.01100  0.00000
# LandContour      F              12.85000  0.00000
# ExterCond        F               8.79900  0.00000
# LotConfig        F               7.81000  0.00000
# RoofMatl         F               6.72700  0.00000
# Condition1       F               6.11800  0.00000
# Heating          F               4.26000  0.00075
# Functional       F               4.05800  0.00048
# Street           F               2.45900  0.11705
# Condition2       F               2.07400  0.04343
# LandSlope        F               1.95900  0.14140
# Utilities        F               0.29900  0.58472

# %%
scatter(df.OverallQual, df.SalePrice)
